# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =  pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# **SPLIT THE DATA**

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.drop(columns = ["median_house_value"])
y = data["median_house_value"]

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %% [markdown]
# **FEATURE ENGINEERING**

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15837    -122.44     37.75                52.0       1573.0           334.0
# 11009    -117.76     33.79                 4.0       8974.0          1268.0
# 10093    -117.96     33.93                29.0       2316.0           522.0
# 4502     -118.20     34.05                43.0       1165.0           317.0
# 16394    -121.25     38.03                29.0       2465.0           327.0
# ...          ...       ...                 ...          ...             ...
# 19087    -122.50     38.35                25.0       1566.0           352.0
# 9395     -122.52     37.89                17.0       4363.0          1041.0
# 16111    -122.50     37.74                44.0       2374.0           496.0
# 19487    -120.99     37.67                28.0       1768.0           423.0
# 5863     -118.34     34.19                47.0       1721.0           343.0
#
# ...

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923590           -0.103496     0.045467
# latitude            -0.923590  1.000000            0.004952    -0.035650
# housing_median_age  -0.103496  0.004952            1.000000    -0.360905
# total_rooms          0.045467 -0.035650           -0.360905     1.000000
# total_bedrooms       0.069921 -0.065776           -0.321060     0.931732
# population           0.099280 -0.107063           -0.293899     0.855781
# households           0.056503 -0.070763           -0.303065     0.919816
# median_income       -0.012086 -0.083387           -0.119638     0.201425
# median_house_value  -0.043629 -0.147318            0.106178     0.132884
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069921    0.099280    0.056503      -0.012086
# latitude                 -0.065776   -0.107063   -0.070763      -0.083387
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] + 1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] + 1)
train_data["population"] = np.log(train_data["population"] + 1)
train_data["households"] = np.log(train_data["households"] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7213
# INLAND        5250
# NEAR OCEAN    2096
# NEAR BAY      1783
# ISLAND           4
# Name: ocean_proximity, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 15837          0       0       0         1           0
# 11009          1       0       0         0           0
# 10093          1       0       0         0           0
# 4502           1       0       0         0           0
# 16394          0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 19087          1       0       0         0           0
# 9395           0       0       0         1           0
# 16111          0       0       0         0           1
# 19487          0       1       0         0           0
# 5863           1       0       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(columns = ["ocean_proximity"])

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15837    -122.44     37.75                52.0     7.361375        5.814131
# 11009    -117.76     33.79                 4.0     9.102198        7.145984
# 10093    -117.96     33.93                29.0     7.748029        6.259581
# 4502     -118.20     34.05                43.0     7.061334        5.762051
# 16394    -121.25     38.03                29.0     7.810353        5.793014
# ...          ...       ...                 ...          ...             ...
# 19087    -122.50     38.35                25.0     7.356918        5.866468
# 9395     -122.52     37.89                17.0     8.381144        6.948897
# 16111    -122.50     37.74                44.0     7.772753        6.208590
# 19487    -120.99     37.67                28.0     7.478170        6.049733
# 5863     -118.34     34.19                47.0     7.451242        5.840642
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = "latitude", y = "longitude", data = train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# **LINEAR REGRESSION MODEL**

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train, y_train = train_data.drop(columns = ["median_house_value"]), train_data["median_house_value"]

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data["total_rooms"] = np.log(test_data["total_rooms"] + 1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] + 1)
test_data["population"] = np.log(test_data["population"] + 1)
test_data["households"] = np.log(test_data["households"] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(columns = ["ocean_proximity"])

test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"] / test_data["households"]

# %%
x_test, y_test = test_data.drop(columns = ["median_house_value"]), test_data["median_house_value"]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15837    -122.44     37.75                52.0     7.361375        5.814131
# 11009    -117.76     33.79                 4.0     9.102198        7.145984
# 10093    -117.96     33.93                29.0     7.748029        6.259581
# 4502     -118.20     34.05                43.0     7.061334        5.762051
# 16394    -121.25     38.03                29.0     7.810353        5.793014
# ...          ...       ...                 ...          ...             ...
# 19087    -122.50     38.35                25.0     7.356918        5.866468
# 9395     -122.52     37.89                17.0     8.381144        6.948897
# 16111    -122.50     37.74                44.0     7.772753        6.208590
# 19487    -120.99     37.67                28.0     7.478170        6.049733
# 5863     -118.34     34.19                47.0     7.451242        5.840642
#
# ...

# %%
model.score(x_test, y_test)
# Out:
# 0.6614180343541307

# %% [markdown]
# **Random Forest Model**

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.8145100898368984

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [30, 50, 100],
    "max_features": [8, 12, 20],
    "min_samples_split": [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)

grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [8, 12, 20],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [30, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_
best_forest
# Out:
# RandomForestRegressor(max_features=12, min_samples_split=4)

# %%
best_forest.score(x_test, y_test)
# Out:
# 0.8154911091450634

# %%
predict = best_forest.predict(x_test)

# %%
predict
# Out:
# array([ 95502.48650794, 351898.12142857, 314083.51190476, ...,
#        193212.90595238,  93935.08690476, 130910.27857143])

# %%
x_train.head(1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15837    -122.44     37.75                52.0     7.361375        5.814131
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 15837     6.58755       5.826         5.0505          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 15837         1           0       0.789816         1.263538

# %%
x_train.columns.tolist()
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  '<1H OCEAN',
#  'INLAND',
#  'ISLAND',
#  'NEAR BAY',
#  'NEAR OCEAN',
#  'bedroom_ratio',
#  'household_rooms']

# %%
input_data = pd.DataFrame([[92.44, 37.75, 52.0, 7.36, 5.8141, 6.58755, 5.826, 5.0505, 1, 0, 0, 1, 0, 0.789816, 12635]],
                          columns = ['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','<1H OCEAN','INLAND','ISLAND','NEAR BAY','NEAR OCEAN','bedroom_ratio','household_rooms'])

# %%
input_data
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      92.44     37.75                52.0         7.36          5.8141
#
#    population  households  median_income  <1H OCEAN  INLAND  ISLAND  NEAR BAY  \
# 0     6.58755       5.826         5.0505          1       0       0         1
#
#    NEAR OCEAN  bedroom_ratio  household_rooms
# 0           0       0.789816            12635

# %%
best_forest.predict(input_data)
# Out:
# array([301915.62869048])

# %%
import pickle as pk

# %%
pk.dump(best_forest, open("forest.pkl", "wb"))
